# %%
import sys
import os
import pandas as pd
import numpy as np 
import matplotlib as plt
import seaborn as sns

sys.path.append(os.path.abspath("../src"))

from crawl_diem_thi import crawl_nhieu_tinh, merge_csv, get_diem_thi

# %%
# Test crawl với một thí sinh
result = get_diem_thi("37", 1)
if result:
    df = pd.DataFrame([result])
    print(df)
else:
    print("Không tìm thấy dữ liệu cho SBD đầu tiên")
# Out:
#   MA_TINH       SBD Toán   Lí   Văn
# 0      37  37000001  8.5  8.5  7.25

# %%
# Thực hiện crawl dữ liệu từ nhiều tỉnh
crawl_nhieu_tinh(1,64)
# Out:
# Bắt đầu crawl tỉnh 01...

# %%
# Merge các file dữ liệu đã thu thập được
merge_csv(folder_path="data", output_file="data/diem_thi_toanquoc.csv")
# Out:
# Không tìm thấy danh sách các file
