# %%
import sys
import os
import pandas as pd
import numpy as np 
import matplotlib as plt
import seaborn as sns

sys.path.append(os.path.abspath("../src"))

from crawl_diem_thi import crawl_nhieu_tinh, merge_csv, get_diem_thi
DATA_PATH = os.path.abspath("../data")

# %%
# Test crawl với một thí sinh
result = get_diem_thi("37", 1,nam_thi=2024)
if result:
    df = pd.DataFrame([result])
    print(df)
else:
    print("Không tìm thấy dữ liệu cho SBD đầu tiên")
# Out:
#    NĂM_THI MA_TINH       SBD Toán   Lí   Hóa  Sinh   Văn Ngoại ngữ
# 0     2024      37  37000001  8.2  8.5  8.25  5.75  7.25       6.4

# %%
# Thực hiện crawl dữ liệu từ nhiều tỉnh
crawl_nhieu_tinh(1,64,nam_thi=2024)
# Out:
# --- BẮT ĐẦU CRAWL TOÀN QUỐC NĂM 2024 ---
#  Bắt đầu crawl tỉnh 01 - Năm 2024...
#  SBD 01000015: {'Toán': '7.6', 'Văn': '9', 'Sử': '7.75', 'Địa': '8.5', 'Ngoại ngữ': '7.6', 'GDCD': '8.75'}
#  SBD 01000008: {'Toán': '8.2', 'Văn': '9', 'Sử': '8', 'Địa': '8.25', 'Ngoại ngữ': '9', 'GDCD': '10'}
#  SBD 01000016: {'Toán': '6', 'Văn': '5.75', 'Sử': '7.75', 'Địa': '7', 'Ngoại ngữ': '6.8', 'GDCD': '7.75'}
#  SBD 01000001: {'Toán': '8.4', 'Lí': '6', 'Hóa': '5.25', 'Sinh': '5', 'Văn': '6.75', 'Ngoại ngữ': '8'}
#  SBD 01000007: {'Toán': '6', 'Văn': '7.5', 'Sử': '6.75', 'Địa': '7', 'GDCD': '7'}
#  SBD 01000020: {'Toán': '7.6', 'Văn': '8.5', 'Sử': '7', 'Địa': '8', 'Ngoại ngữ': '9.2', 'GDCD': '7.75'}
#  SBD 01000003: {'Toán': '8.2', 'Văn': '8.75', 'Sử': '7.25', 'Địa': '7.25', 'Ngoại ngữ': '8.2', 'GDCD': '8.75'}
#  SBD 01000013: {'Toán': '5.2', 'Văn': '8', 'Sử': '7.5', 'Địa': '5.75', 'Ngoại ngữ': '8.6', 'GDCD': '8'}
#  SBD 01000005: {'Toán': '8.6', 'Văn': '9', 'Sử': '9', 'Địa': '8.75', 'Ngoại ngữ': '7.8', 'GDCD': '8.5'}
#  SBD 01000018: {'Toán': '8.2', 'Lí': '7.75', 'Hóa': '6.75', 'Sinh': '6.75', 'Văn': '6', 'Ngoại ngữ': '9'}
#  SBD 01000009: {'Toán': '8.2', 'Lí': '8.25', 'Hóa': '4.25', 'Sinh': '6', 'Văn': '8', 'Ngoại ngữ': '8.6'}
#  SBD 01000014: {'Toán': '7.6', 'Văn': '9', 'Sử': '7.25', 'Địa': '7.5', 'Ngoại ngữ': '7.4', 'GDCD': '7.5'}
#  SBD 01000019: {'Toán': '2.8', 'Văn': '4.25', 'Sử': '5.75', 'Địa': '7'}
#  SBD 01000002: {'Toán': '8.6', 'Văn': '8.5', 'Sử': '7.25', 'Địa': '6', 'Ngoại ngữ': '7.2', 'GDCD': '8'}
#  SBD 01000012: {'Toán': '8.2', 'Văn': '8', 'Sử': '7.75', 'Địa': '9.5', 'Ngoại ngữ': '8.2', 'GDCD': '9'}
#  SBD 01000006: {'Toán': '5.8', 'Văn': '8.75', 'Sử': '7.75', 'Địa': '6.75', 'Ngoại ngữ': '7.8', 'GDCD': '7.5'}
#  SBD 01000004: {'Toán': '4.8', 'Văn': '8.5', 'Sử': '7', 'Địa': '6', 'Ngoại ngữ': '7.4', 'GDCD': '7.5'}
#  SBD 01000017: {'Toán': '7', 'Lí': '3.75', 'Hóa': '7.5', 'Sinh': '7.25', 'Văn': '8.75', 'Ngoại ngữ': '7.8'}
#  SBD 01000010: {'Toán': '7.4', 'Văn': '9', 'Sử': '8.25', 'Địa': '6.5', 'Ngoại ngữ': '9.6', 'GDCD': '8.25'}
#  SBD 01000022: {'Văn': '4.25', 'Sử': '5.75', 'Địa': '6.25'}
#  SBD 01000011: {'Toán': '7.2', 'Lí': '7.75', 'Hóa': '6.75', 'Sinh': '6.25', 'Văn': '8.5', 'Ngoại ngữ': '9'}
#  SBD 01000023: {'Toán': '8.8', 'Lí': '8.5', 'Hóa': '6.5', 'Sinh': '7', 'Văn': '9.25', 'Ngoại ngữ': '8.8'}
#  SBD 01000024: {'Toán': '8.4', 'Văn': '9.5', 'Sử': '7.25', 'Địa': '8.75', 'Ngoại ngữ': '8.8', 'GDCD': '8.25'}
#  SBD 01000021: {'Toán': '8.4', 'Lí': '2.5', 'Hóa': '8.75', 'Sinh': '7.75', 'Văn': '8.5', 'Ngoại ngữ': '8.6'}
#  SBD 01000027: {'Toán': '8.2', 'Lí': '6.25', 'Hóa': '9', 'Sinh': '5.75', 'Văn': '8.75', 'Ngoại ngữ': '8'}
#  SBD 01000026: {'Toán': '7.2', 'Lí': '7.5', 'Hóa': '8.75', 'Sinh': '8.75', 'Văn': '8.25'}
#  SBD 01000029: {'Văn': '6.25', 'Sử': '5', 'Địa': '5.5'}
#  SBD 01000028: {'Toán': '8.8', 'Văn': '8.5', 'Sử': '8.25', 'Địa': '8.5', 'Ngoại ngữ': '9', 'GDCD': '8.75'}
#  SBD 01000030: {'Toán': '8', 'Lí': '7', 'Hóa': '2', 'Sinh': '3.75', 'Văn': '7.75', 'Ngoại ngữ': '7.4'}
#  SBD 01000025: {'Toán': '7.8', 'Văn': '9.25', 'Sử': '7', 'Địa': '7.5', 'Ngoại ngữ': '8.4', 'GDCD': '7.75'}
#  SBD 01000031: {'Toán': '6.8', 'Văn': '9.5', 'Sử': '8.5', 'Địa': '7.75', 'Ngoại ngữ': '8.4', 'GDCD': '9'}
#  SBD 01000032: {'Toán': '8.2', 'Văn': '8.75', 'Sử': '8.75', 'Địa': '9', 'Ngoại ngữ': '7', 'GDCD': '8.5'}
#  SBD 01000039: {'Toán': '7.2', 'Văn': '5.75', 'Sử': '7.75', 'Địa': '7.25', 'Ngoại ngữ': '5.6', 'GDCD': '7.5'}
#  SBD 01000041: {'Toán': '6.2', 'Lí': '7.25', 'Hóa': '7', 'Sinh': '5.75', 'Văn': '7.75', 'Ngoại ngữ': '8.2'}
#  SBD 01000036: {'Toán': '6.4', 'Lí': '2.5', 'Hóa': '3.5', 'Sinh': '4.5', 'Văn': '7.25', 'Ngoại ngữ': '4.8'}
#  SBD 01000046: {'Toán': '7.8', 'Lí': '7', 'Hóa': '5.5', 'Sinh': '6.25', 'Văn': '8.25', 'Ngoại ngữ': '9.2'}
#  SBD 01000035: {'Toán': '8', 'Lí': '5', 'Hóa': '7.25', 'Sinh': '4.75', 'Văn': '7.5', 'Ngoại ngữ': '8.4'}
#  SBD 01000040: {'Toán': '7', 'Văn': '7.75', 'Sử': '6.75', 'Địa': '6', 'Ngoại ngữ': '6', 'GDCD': '8.25'}
#  SBD 01000038: {'Toán': '8.2', 'Văn': '9', 'Sử': '7.75', 'Địa': '8.25', 'Ngoại ngữ': '8.6', 'GDCD': '8.75'}
#  SBD 01000037: {'Toán': '7.6', 'Văn': '8.75', 'Sử': '8', 'Địa': '7.25', 'Ngoại ngữ': '9.2', 'GDCD': '7.75'}
#  SBD 01000034: {'Toán': '7.8', 'Văn': '9.25', 'Sử': '7.75', 'Địa': '8', 'Ngoại ngữ': '7.8', 'GDCD': '8.25'}
#  SBD 01000044: {'Toán': '9', 'Lí': '8.5', 'Hóa': '8.5', 'Sinh': '6.5', 'Văn': '7.75', 'Ngoại ngữ': '7.6'}
#  SBD 01000047: {'Toán': '4.8', 'Văn': '8.5', 'Sử': '9.25', 'Địa': '9.5'}
#  SBD 01000043: {'Toán': '8', 'Lí': '8.25', 'Hóa': '6', 'Sinh': '7', 'Văn': '8', 'Ngoại ngữ': '9.6'}
#  SBD 01000050: {'Toán': '8', 'Văn': '9.25', 'Sử': '8', 'Địa': '8', 'Ngoại ngữ': '9.4', 'GDCD': '8.5'}
#  SBD 01000051: {'Toán': '6.6', 'Văn': '8', 'Sử': '7.75', 'Địa': '7.75', 'Ngoại ngữ': '4.8', 'GDCD': '8.75'}
#  SBD 01000045: {'Văn': '4', 'Sử': '7.25', 'Địa': '6.5'}
#  SBD 01000033: {'Toán': '8.6', 'Văn': '9.5', 'Sử': '9', 'Địa': '8', 'Ngoại ngữ': '9.2', 'GDCD': '9'}
#  SBD 01000042: {'Toán': '7', 'Văn': '8.5', 'Sử': '5.5', 'Địa': '5', 'Ngoại ngữ': '7', 'GDCD': '7'}
#  SBD 01000053: {'Toán': '8', 'Lí': '3.25', 'Hóa': '8.25', 'Sinh': '5.5', 'Văn': '8.75', 'Ngoại ngữ': '6.8'}
#  SBD 01000049: {'Toán': '7.6', 'Lí': '5.5', 'Hóa': '5.5', 'Sinh': '6.25', 'Văn': '6.5', 'Ngoại ngữ': '8.6'}
#  SBD 01000048: {'Toán': '6.8', 'Văn': '5.5', 'Sử': '5.75', 'Địa': '6.75', 'Ngoại ngữ': '6', 'GDCD': '7.25'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Thực hiện crawl dữ liệu từ nhiều tỉnh
# ----> 2 crawl_nhieu_tinh(1,64,nam_thi=2024)
#
# File d:\Documents University\Semester 5\Intro DS\Project\introduction-to-data-science-feature-crawl-diem-thi\src\crawl_diem_thi.py:134, in crawl_nhieu_tinh(start_tinh, end_tinh, nam_thi)
#     131 ma_tinh_str = f"{id_tinh:02d}"
#     133 try:
# --> 134     crawl_tinh(ma_tinh=ma_tinh_str, nam_thi=nam_thi)
#     135     print(f" Đã xong tỉnh {ma_tinh_str} (Năm {nam_thi})")
#     137 except Exception as e:
#
# File d:\Documents University\Semester 5\Intro DS\Project\introduction-to-data-science-feature-crawl-diem-thi\src\crawl_diem_thi.py:97, in crawl_tinh(ma_tinh, nam_thi, max_empty, max_workers)
#      91 with ThreadPoolExecutor(max_workers=max_workers) as executor:
#      92     futures = {
#      93         executor.submit(get_diem_thi, ma_tinh, num, nam_thi): num
#      94         for num in sbd_batch
#      95     }
# ---> 97     for future in as_completed(futures):
#      98         data = future.result()
#      99         if data:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
# Merge các file dữ liệu đã thu thập được
merge_csv(folder_path=DATA_PATH,nam_thi=2025)
# Out:
#  Tìm thấy 2 file dữ liệu năm 2025. Đang gộp...
#  - Đã nạp: diem_thi_2025_01.csv
#  - Đã nạp: diem_thi_2025_02.csv
#  Đã gộp xong! File lưu tại: d:\Documents University\Semester 5\Intro DS\Project\introduction-to-data-science-feature-crawl-diem-thi\data\diem_thi_toan_quoc_2025.csv
#  Tổng số dòng dữ liệu: 889388
